# %% [markdown]
# <a href="https://colab.research.google.com/github/sajib006/Data-Cleaning/blob/main/datacleaing1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv('/content/drive/MyDrive/laptopData.csv')
dataset.head(3)
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz  8GB            128GB SSD
# 1        Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz  8GB            256GB SSD
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg  47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg  30636.0000

# %%
dataset.shape
# Out:
# (1303, 12)

# %%
dataset.shape[0]
# Out:
# 1303

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(360)

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Unnamed: 0          2.302379
# Company             2.302379
# TypeName            2.302379
# Inches              2.302379
# ScreenResolution    2.302379
# Cpu                 2.302379
# Ram                 2.302379
# Memory              2.302379
# Gpu                 2.302379
# OpSys               2.302379
# Weight              2.302379
# Price               2.302379
# dtype: float64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(2.3023791250959325)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
#dataset.drop(columns=["Cpu"],inplace=True)

# %%
#dataset.dropna(inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
#dataset.fillna(10).head(10)
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5         5.0    Acer   Notebook   15.6                            1366x768
# 6         6.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 7         7.0   Apple  Ultrabook   13.3                            1440x900
# 8         8.0    Asus  Ultrabook     14                   Full HD 1920x1080
# 9         9.0    Acer  Ultrabook     14         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# ...

# %%
dataset.fillna(method="bfill")
# Out:
# /tmp/ipython-input-193979722.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill")
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# ...
